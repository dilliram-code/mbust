# %% [markdown]
# #####   `class time`: every Friday, 2:30 - 4:00 (PM)

# %% [markdown]
# #### ❇️ Course: Research Methodology for Data Science |
# #### 				Research Methodology for Intelligent Systems
#
# #### Assignment folder link: https://mbustb-my.sharepoint.com/personal/yalamber_ingnam_mbust_edu_np/_layouts/15/onedrive.aspx?id=%2Fpersonal%2Fyalamber%5Fingnam%5Fmbust%5Fedu%5Fnp%2FDocuments%2FResearch%20Methodology%20by%20Prof%20Ved%20P%20Kafle%2FAssignments&viewid=f3e87dd0%2D0146%2D4658%2Dbaf1%2D3cf88d7c90b6

# %% [markdown]
# ##### ✅ Tutor Introduction:
# - `Name`: Ved P. Kafle
# - `Contact No.`: +81 8097132852 (Japana)
# - `emal` : kafle@nict.go.jp (office) | ved.kafle@gmail.com (private)
# - `what can I ask?`: for IEEE research papers downloading

# %% [markdown]
# `DATE`: May 22, 2026 | 2:30 - 4:00
# ##### Reading Assignment: https://myrepublica.nagariknetwork.com/news/toward-society-5-0

# %% [markdown]
# ##### Research Assignments:
#
# #### First Lecture Assignment:
# - 1. What is research methodology?
# - 2. What are the differences between research methodology and research methods?
# - 3. What are the differences between research and consulting services?

# %% [markdown]
# #### Second Lecture Assignment:
# - 1.⁠ ⁠What is research? Write a one sentence definition in your own words. Additionally, enlist key terms or characteristics that describe research.
#
# - 2.⁠ ⁠What are the different types of research? Try to identify as many as possible.
#
# - 3.⁠ ⁠What are the different research methods? Provide examples of the methods commonly used in scientific research and social research.
