# %% [markdown]
# #####   `class time`: every Friday, 2:30 - 4:00 (PM)

# %% [markdown]
# #### ❇️ Course: Research Methodology for Data Science |
# #### 				Research Methodology for Intelligent Systems

# %% [markdown]
# ##### ✅ Tutor Introduction:
# - `Name`: Ved P. Kafle
# - `Contact No.`: +81 8097132852 (Japana)
# - `emal` : kafle@nict.go.jp (office) | ved.kafle@gmail.com (private)
# - `what can I ask?`: for IEEE research papers downloading

# %% [markdown]
# `DATE`: May 22, 2026 | 2:30 - 4:00
# ##### Reading Assignment: https://myrepublica.nagariknetwork.com/news/toward-society-5-0

# %% [markdown]
# ##### Research Assignments:
# - 1. What is research methodology?
# - 2. What are the differences between research methodology and research methods?
# - 3. What are the differences between research and consulting services?
